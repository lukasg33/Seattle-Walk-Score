# %%
# import packages
import pandas as pd
import json
#import osmnx as ox
import requests
import random
import time

# %%
new = pd.read_csv('Data/master_features.csv', index_col=0)

# %%
new.head()
# Out:
#     lat_left    lon_left        GEOID  restaurant_count  school_count  \
# 0  47.648701 -122.362286  53033005901                10             1
# 1  47.658157 -122.373453  53033005901                10             0
# 2  47.653362 -122.370374  53033005901                 8             1
# 3  47.694938 -122.304282  53033002100                 2             5
# 4  47.690396 -122.305112  53033002100                 5             5
#
#    park_count  bus_station_count  supermarket_count  pub_count  \
# 0           5                  3                  1          9
# 1           2                  1                  4         10
# 2           3                  1                  0          3
# 3           2                  7                  0          2
# 4           4                  7                  0          3
#
#    parkwide_count  ...         zone  population  AREA_ACRES  tract  \
# 0              10  ...   industrial        3570  235.297362   5901
# ...

# %%
apikey = 'ecfba8ed1b0d55fecba1ce58615fe3e8'

# %%
# set empty walk_score list
walk_score = []

for i in range(len(new['lat_left'])):
    url = 'http://api.walkscore.com/score?format=json&lat='+str(new['lat_left'][i])+'&lon='+str(new['lon_left'][i])+'&wsapikey='+apikey
    r = requests.get(url)
    data = r.json()
    if 'walkscore' in data:
        walk_score.append(data['walkscore'])
    else:
        walk_score.append('N/A')
        
    time.sleep(0.2)

# %%
url = 'http://api.walkscore.com/score?format=json&lat='+str(new['lat_left'][0])+'&lon='+str(new['lon_left'][0])+'&wsapikey='+apikey
r = requests.get(url)
data = r.json()
data['walkscore']
# Out:
# 70

# %%
# create dataframe
new['walk_score'] = walk_score
new.info()
new.head(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 629 entries, 0 to 628
# Data columns (total 46 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   lat_left              629 non-null    float64
#  1   lon_left              629 non-null    float64
#  2   GEOID                 629 non-null    int64
#  3   restaurant_count      629 non-null    int64
#  4   school_count          629 non-null    int64
#  5   park_count            629 non-null    int64
#  6   bus_station_count     629 non-null    int64
#  7   supermarket_count     629 non-null    int64
#  8   pub_count             629 non-null    int64
#  9   parkwide_count        629 non-null    int64
#  10  restaurantwide_count  629 non-null    int64
#  11  intersection_count    629 non-null    int64
#  12  streets_per_node_avg  629 non-null    float64
#  13  circuity_avg          629 non-null    float64
#  14  street_length_avg     629 non-null    float64
# ...
